# %%
import pandas as pd
import requests
import yfinance as yf

# %%
from src.Data.accounting_info import Sec_Data_Restructure

# %%
a = Sec_Data_Restructure('aapl')

# %%
a.share_compose()
# Out:
#                         shares
# ticker date
# AAPL   2009-06-27    895816758
#        2009-10-16    900678473
#        2010-01-15    906794589
#        2010-04-09    909938383
#        2010-07-09    913562880
# ...                        ...
#        2025-04-18  14935826000
#        2025-07-18  14840390000
#        2025-10-17  14776353000
#        2026-01-16  14681140000
#        2026-04-17  14687356000
#
# [68 rows x 1 columns]
